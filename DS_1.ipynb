# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Replace the NaN values with correct value. And justify why you have chosen the same ?

# %%
dataset.isna().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanQual(dataset)
# Out:
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             2
# gender            2
# ssc_p             2
# ssc_b             2
# hsc_p             2
# hsc_b             2
# hsc_s             2
# degree_p          2
# degree_t          2
# workex            2
# etest_p           2
# specialisation    2
# mba_p             2
# status            2
# salary            0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 212  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 213  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 214  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 215  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 216  215.0  62.00  58.00     53.00     89.0  60.22       0.0
#
# [217 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# sl_no       0
# ssc_p       0
# hsc_p       0
# degree_p    0
# etest_p     0
# mba_p       0
# salary      0
# dtype: int64

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan,strategy="most_frequent")
imp.fit(dataset[qual])
df1=imp.transform(dataset[qual])
df1 = pd.DataFrame(df1,columns =qual)

# %%
df1
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 3        M  Central  Central   Science   Sci&Tech     No         Mkt&HR
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 212      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 213      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 214      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 215      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
# 216      M  Central   Others   Science  Comm&Mgmt     No         Mkt&HR
#
#          status
# 0        Placed
# 1        Placed
# 2        Placed
# 3    Not Placed
# ...

# %%
df1.isnull().sum()
# Out:
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset1=[df,df1]

# %%
dataset1=pd.concat(dataset1,axis=1)

# %%
dataset1
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 212  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 213  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 214  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 215  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 216  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset1.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset1.to_csv("placement_data_.csv",index=False)

# %% [markdown]
#  # How many of them are not placed?

# %%
dataset1[dataset1['status'] == 'Not Placed']
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  salary gender    ssc_b  \
# 3      4.0   56.0   52.0     52.00    66.00  59.43     0.0      M  Central
# 5      6.0   55.0   49.8     67.25    55.00  51.58     0.0      M   Others
# 6      7.0   46.0   49.2     79.00    74.28  53.29     0.0      F   Others
# 11    10.0   58.0   70.0     61.00    54.00  52.21     0.0      M  Central
# 14    13.0   47.0   55.0     65.00    62.00  65.04     0.0      F  Central
# ..     ...    ...    ...       ...      ...    ...     ...    ...      ...
# 200  199.0   67.0   70.0     65.00    88.00  71.96     0.0      F  Central
# 203  202.0   54.2   63.0     58.00    79.00  58.44     0.0      M  Central
# 208  207.0   41.0   42.0     60.00    97.00  53.39     0.0      M  Central
# 210  209.0   43.0   60.0     65.00    92.66  62.92     0.0      F  Central
# 216  215.0   62.0   58.0     53.00    89.00  60.22     0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset2 = dataset[dataset['status'] == 'Not Placed']

# %%
dataset2_count = len(dataset2)

# %%
print("  NOT PLACED :",dataset2_count)
# Out:
#   NOT PLACED : 67

# %% [markdown]
# # What kind of relation between salary and mba_p

# %%
dataset3=dataset1[["salary","mba_p"]]

# %%
#inc,dic to pas,neg
dataset3.corr()
# Out:
#           salary     mba_p
# salary  1.000000  0.138768
# mba_p   0.138768  1.000000

# %% [markdown]
# # How many of them getting above 500000 salary

# %%
salary_rows= dataset1[dataset1['salary'] > 500000]

# %%
above_salary = salary_rows.shape[0]

# %%
print("How many of them getting above 500000 salary:", above_salary)
# Out:
# How many of them getting above 500000 salary: 3

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement_Data_.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 212  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 213  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 214  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 215  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 216  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...
